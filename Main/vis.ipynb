# %%
import pandas as pd
trees_us = pd.read_csv("../../data/greenspace_data/5_million_trees_us_cities_cleaned.csv")

# %%
# trees_us.info()

# %%
trees_us.isnull().sum()
# Out:
# common_name                   114106
# scientific_name               529237
# city                               0
# state                              0
# longitude_coordinate               0
# latitude_coordinate                0
# location_type                      0
# zipcode                            0
# diameter_breast_height_CM          0
# condition                          0
# native                             0
# greater_metro                      0
# height_M                           0
# planted_year                 5215443
# planted_month                5238997
# planted_day                  5239431
# dtype: int64

# %%
df = pd.read_csv("../../clean_data/greenspace_data/percent_cover_county.txt", sep = ",")
df.info()
df.hist()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3101 entries, 0 to 3100
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   GEOID        3101 non-null   int64
#  1   NAME         3101 non-null   object
#  2   pc_park      3101 non-null   float64
#  3   state        3101 non-null   object
#  4   state_name   3101 non-null   object
#  5   county_name  3101 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 145.5+ KB
# array([[<AxesSubplot: title={'center': 'GEOID'}>,
#         <AxesSubplot: title={'center': 'pc_park'}>]], dtype=object)

# %%
df = pd.read_csv("../../clean_data/greenspace_data/percent_cover_tracts_no_buffer.txt", sep = ",")
df.info()
df.hist()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72538 entries, 0 to 72537
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   GEOID        72538 non-null  int64
#  1   STATEFP      72538 non-null  int64
#  2   COUNTYFP     72538 non-null  int64
#  3   pc_park      72538 non-null  float64
#  4   state        72538 non-null  object
#  5   state_name   72538 non-null  object
#  6   county_name  72538 non-null  object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 3.9+ MB
# array([[<AxesSubplot: title={'center': 'GEOID'}>,
#         <AxesSubplot: title={'center': 'STATEFP'}>],
#        [<AxesSubplot: title={'center': 'COUNTYFP'}>,
#         <AxesSubplot: title={'center': 'pc_park'}>]], dtype=object)

# %%
df = pd.read_csv("../../clean_data/greenspace_data/percent_cover_tracts_with_buffer.txt", sep = ",")
df.info()
df.hist()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72538 entries, 0 to 72537
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   GEOID        72538 non-null  int64
#  1   STATEFP      72538 non-null  int64
#  2   COUNTYFP     72538 non-null  int64
#  3   pc_park      72538 non-null  float64
#  4   state        72538 non-null  object
#  5   state_name   72538 non-null  object
#  6   county_name  72538 non-null  object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 3.9+ MB
# array([[<AxesSubplot: title={'center': 'GEOID'}>,
#         <AxesSubplot: title={'center': 'STATEFP'}>],
#        [<AxesSubplot: title={'center': 'COUNTYFP'}>,
#         <AxesSubplot: title={'center': 'pc_park'}>]], dtype=object)

# %%
df.state_name.value_counts()

mask = df.state_name.isin(["New York", "New Jersey"])
df_nyc = df[mask]

# %%
df_nyc
# Out:
#              GEOID  STATEFP  COUNTYFP  pc_park state  state_name  \
# 39989  34031256804       34        31   26.116    NJ  New Jersey
# 39990  34031246300       34        31    5.240    NJ  New Jersey
# 39991  34031181200       34        31    3.436    NJ  New Jersey
# 39992  34031256803       34        31   35.361    NJ  New Jersey
# 39993  34031246003       34        31   10.696    NJ  New Jersey
# ...            ...      ...       ...      ...   ...         ...
# 47411  36081027900       36        81    1.568    NY    New York
# 47412  36081028000       36        81   11.305    NY    New York
# 47413  36081028100       36        81    1.588    NY    New York
# 47414  36081028200       36        81   10.302    NY    New York
# 47415  36081028400       36        81   15.569    NY    New York
#
#               county_name
# 39989  Carolina Municipio
# 39990  Carolina Municipio
# 39991  Carolina Municipio
# 39992  Carolina Municipio
# 39993  Carolina Municipio
# ...

# %%
df = pd.read_csv("../../clean_data/greenspace_data/percent_cover_zipcode_tabulated_areas.txt", sep = ",")

# %%
df_nyc = df[df.state_name.isin(["New York", "New Jersey"])]

# %%
df_nyc
# Out:
#        ZCTA5CE10  pc_park  state_fip state_abb  state_name  county_fip  \
# 1747       14135    1.354         36        NY    New York          13
# 1748       14136    0.202         36        NY    New York          13
# 1749       14138    0.062         36        NY    New York          13
# 1750       14139    3.139         36        NY    New York          29
# 1751       14141    0.173         36        NY    New York          29
# ...          ...      ...        ...       ...         ...         ...
# 32363       7503    0.721         34        NJ  New Jersey          31
# 32572       7504   10.746         34        NJ  New Jersey          31
# 32573       7505    0.755         34        NJ  New Jersey          31
# 32575       7506    5.873         34        NJ  New Jersey          31
# 32577       7508    2.641         34        NJ  New Jersey          31
#
#                county_name
# 1747     Arecibo Municipio
# 1748     Arecibo Municipio
# 1749     Arecibo Municipio
# ...
